# %% [markdown]
# <a href="https://colab.research.google.com/github/joyngeno21-ui/Joy-AI-Assignment/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-j3j40aws
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-j3j40aws
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1bef2cd4db82c6c4cfb3982e92b83db41f2274fecc2111854636431281d001d5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w6h5tq8j/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.582226, train error 61.70,  val loss 1.663876, percent error 66.90
# Epoch     1, train loss 1.345946, train error 51.03,  val loss 1.497205, percent error 60.30
# Epoch     2, train loss 1.146297, train error 41.42,  val loss 1.339493, percent error 52.60
# Epoch     3, train loss 1.005816, train error 35.80,  val loss 1.240884, percent error 47.40
# Epoch     4, train loss 0.923017, train error 33.82,  val loss 1.218960, percent error 45.90
# Epoch     5, train loss 0.797981, train error 28.47,  val loss 1.152293, percent error 43.50
# Epoch     6, train loss 0.694057, train error 24.15,  val loss 1.145067, percent error 42.10
# Epoch     7, train loss 0.671627, train error 24.18,  val loss 1.182344, percent error 43.50
# Epoch     8, train loss 0.546367, train error 18.53,  val loss 1.069459, percent error 38.20
# Epoch     9, train loss 0.541054, train error 18.47,  val loss 1.125399, percent error 40.80
# Epoch    10, train loss 0.438808, train error 14.15,  val loss 1.089617, percent error 38.20
# Epoch    11, train loss 0.392755, train error 12.30,  val loss 1.080994, percent error 36.80
# Epoch    12, train loss 0.348635, train error 10.12,  val loss 1.082052, percent error 37.90
# Epoch    13, train loss 0.363160, train error 12.00,  val loss 1.165384, percent error 39.00
# Epoch    14, train loss 0.269262, train error 7.93,  val loss 1.152175, percent error 38.30
# Epoch    15, train loss 0.243857, train error 6.75,  val loss 1.164741, percent error 38.10
# Epoch    16, train loss 0.243847, train error 7.40,  val loss 1.292989, percent error 38.90
# Epoch    17, train loss 0.185065, train error 5.00,  val loss 1.287810, percent error 38.40
# Epoch    18, train loss 0.168558, train error 4.57,  val loss 1.285592, percent error 38.30
# Epoch    19, train loss 0.162445, train error 4.38,  val loss 1.334437, percent error 37.90
# Epoch    20, train loss 0.086437, train error 0.78,  val loss 1.253188, percent error 37.20
# Epoch    21, train loss 0.063292, train error 0.28,  val loss 1.253426, percent error 35.90
# Epoch    22, train loss 0.057204, train error 0.18,  val loss 1.282485, percent error 36.20
# Epoch    23, train loss 0.050322, train error 0.07,  val loss 1.299646, percent error 36.50
# Epoch    24, train loss 0.044867, train error 0.03,  val loss 1.325944, percent error 35.00
# Epoch    25, train loss 0.042356, train error 0.00,  val loss 1.337827, percent error 35.30
# Epoch    26, train loss 0.038221, train error 0.03,  val loss 1.364225, percent error 35.80
# Epoch    27, train loss 0.034453, train error 0.00,  val loss 1.366256, percent error 35.70
# Epoch    28, train loss 0.031927, train error 0.00,  val loss 1.388866, percent error 35.40
# Epoch    29, train loss 0.029235, train error 0.00,  val loss 1.401112, percent error 36.00
# Epoch    30, train loss 0.027865, train error 0.00,  val loss 1.425645, percent error 35.40
# Epoch    31, train loss 0.026555, train error 0.00,  val loss 1.434262, percent error 35.50
# Epoch    32, train loss 0.024235, train error 0.00,  val loss 1.444649, percent error 36.20
# Epoch    33, train loss 0.022817, train error 0.00,  val loss 1.465221, percent error 35.50
# Epoch    34, train loss 0.021883, train error 0.00,  val loss 1.470906, percent error 35.80
# Epoch    35, train loss 0.020374, train error 0.00,  val loss 1.487263, percent error 36.10
# Epoch    36, train loss 0.019345, train error 0.00,  val loss 1.500741, percent error 35.70
# Epoch    37, train loss 0.018464, train error 0.00,  val loss 1.515625, percent error 35.70
# Epoch    38, train loss 0.017554, train error 0.00,  val loss 1.523792, percent error 35.90
# Epoch    39, train loss 0.016750, train error 0.00,  val loss 1.525622, percent error 36.00
# Epoch    40, train loss 0.016115, train error 0.00,  val loss 1.539393, percent error 35.70
# Epoch    41, train loss 0.015748, train error 0.00,  val loss 1.543209, percent error 35.70
# Epoch    42, train loss 0.015438, train error 0.00,  val loss 1.547162, percent error 35.80
# Epoch    43, train loss 0.015120, train error 0.00,  val loss 1.553830, percent error 35.50
# Epoch    44, train loss 0.014835, train error 0.00,  val loss 1.558070, percent error 35.60
# Epoch    45, train loss 0.014552, train error 0.00,  val loss 1.565561, percent error 35.50
# Epoch    46, train loss 0.014266, train error 0.00,  val loss 1.574199, percent error 35.80
# Epoch    47, train loss 0.013975, train error 0.00,  val loss 1.574767, percent error 35.70
# Epoch    48, train loss 0.013737, train error 0.00,  val loss 1.577867, percent error 36.00
# Epoch    49, train loss 0.013553, train error 0.00,  val loss 1.581587, percent error 36.10
# Epoch    50, train loss 0.013242, train error 0.00,  val loss 1.589164, percent error 35.70
# Epoch    51, train loss 0.012996, train error 0.00,  val loss 1.597137, percent error 35.80
# Epoch    52, train loss 0.012850, train error 0.00,  val loss 1.599362, percent error 35.90
# Epoch    53, train loss 0.012548, train error 0.00,  val loss 1.601747, percent error 35.70
# Epoch    54, train loss 0.012324, train error 0.00,  val loss 1.608087, percent error 35.50
# Epoch    55, train loss 0.012108, train error 0.00,  val loss 1.609701, percent error 35.70
# Epoch    56, train loss 0.011973, train error 0.00,  val loss 1.614055, percent error 35.80
# Epoch    57, train loss 0.011743, train error 0.00,  val loss 1.617805, percent error 35.50
# Epoch    58, train loss 0.011535, train error 0.00,  val loss 1.623774, percent error 35.80
# Epoch    59, train loss 0.011328, train error 0.00,  val loss 1.627916, percent error 35.80
# Epoch    60, train loss 0.011213, train error 0.00,  val loss 1.630241, percent error 35.70
# Epoch    61, train loss 0.011123, train error 0.00,  val loss 1.629566, percent error 35.70
# Epoch    62, train loss 0.011038, train error 0.00,  val loss 1.633051, percent error 35.80
# Epoch    63, train loss 0.010952, train error 0.00,  val loss 1.635864, percent error 35.80
# Epoch    64, train loss 0.010865, train error 0.00,  val loss 1.635388, percent error 35.90
# Epoch    65, train loss 0.010801, train error 0.00,  val loss 1.638432, percent error 35.80
# Epoch    66, train loss 0.010699, train error 0.00,  val loss 1.641734, percent error 35.70
# Epoch    67, train loss 0.010617, train error 0.00,  val loss 1.643402, percent error 35.80
# Epoch    68, train loss 0.010536, train error 0.00,  val loss 1.645370, percent error 35.80
# Epoch    69, train loss 0.010459, train error 0.00,  val loss 1.645809, percent error 35.80
# Epoch    70, train loss 0.010384, train error 0.00,  val loss 1.648439, percent error 35.80
# Epoch    71, train loss 0.010304, train error 0.00,  val loss 1.650317, percent error 35.80
# Epoch    72, train loss 0.010238, train error 0.00,  val loss 1.653856, percent error 36.00
# Epoch    73, train loss 0.010161, train error 0.00,  val loss 1.654064, percent error 35.80
# Epoch    74, train loss 0.010085, train error 0.00,  val loss 1.656214, percent error 35.90
# Epoch    75, train loss 0.010009, train error 0.00,  val loss 1.657987, percent error 35.80
# Epoch    76, train loss 0.009943, train error 0.00,  val loss 1.658998, percent error 35.70
# Epoch    77, train loss 0.009863, train error 0.00,  val loss 1.660637, percent error 35.80
# Epoch    78, train loss 0.009814, train error 0.00,  val loss 1.661844, percent error 35.90
# Epoch    79, train loss 0.009727, train error 0.00,  val loss 1.664153, percent error 35.80
# Epoch    80, train loss 0.009687, train error 0.00,  val loss 1.664935, percent error 35.80
# Epoch    81, train loss 0.009652, train error 0.00,  val loss 1.665997, percent error 35.80
# Epoch    82, train loss 0.009618, train error 0.00,  val loss 1.667126, percent error 35.80
# Epoch    83, train loss 0.009584, train error 0.00,  val loss 1.668520, percent error 35.80
# Epoch    84, train loss 0.009551, train error 0.00,  val loss 1.669041, percent error 35.80
# Epoch    85, train loss 0.009519, train error 0.00,  val loss 1.669529, percent error 35.90
# Epoch    86, train loss 0.009485, train error 0.00,  val loss 1.670482, percent error 35.90
# Epoch    87, train loss 0.009452, train error 0.00,  val loss 1.671714, percent error 35.90
# Epoch    88, train loss 0.009421, train error 0.00,  val loss 1.672552, percent error 35.80
# Epoch    89, train loss 0.009388, train error 0.00,  val loss 1.673163, percent error 35.80
# Epoch    90, train loss 0.009357, train error 0.00,  val loss 1.673972, percent error 35.90
# Epoch    91, train loss 0.009326, train error 0.00,  val loss 1.674909, percent error 35.90
# Epoch    92, train loss 0.009293, train error 0.00,  val loss 1.675491, percent error 35.80
# Epoch    93, train loss 0.009261, train error 0.00,  val loss 1.676305, percent error 35.90
# Epoch    94, train loss 0.009231, train error 0.00,  val loss 1.678005, percent error 36.00
# Epoch    95, train loss 0.009200, train error 0.00,  val loss 1.678117, percent error 35.90
# Epoch    96, train loss 0.009169, train error 0.00,  val loss 1.679376, percent error 35.90
# Epoch    97, train loss 0.009138, train error 0.00,  val loss 1.680223, percent error 35.90
# Epoch    98, train loss 0.009109, train error 0.00,  val loss 1.680723, percent error 35.90
# Epoch    99, train loss 0.009077, train error 0.00,  val loss 1.681499, percent error 36.00
