# %% [markdown]
# <a href="https://colab.research.google.com/github/joyngeno21-ui/Joy-AI-Assignment/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-sp61sw65
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-sp61sw65
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=17acf793b18cd5e36726ff1e87ab44e46efefe5ee0b1d381b1b6f5d4790675dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p1eyo9v4/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.604806, train error 63.30,  val loss 1.686226, percent error 67.60
# Epoch     1, train loss 1.318037, train error 49.28,  val loss 1.437353, percent error 56.50
# Epoch     2, train loss 1.210463, train error 46.72,  val loss 1.411042, percent error 54.10
# Epoch     3, train loss 0.954028, train error 34.97,  val loss 1.219081, percent error 47.60
# Epoch     4, train loss 0.833110, train error 31.25,  val loss 1.218032, percent error 47.10
# Epoch     5, train loss 0.711495, train error 24.53,  val loss 1.126093, percent error 42.70
# Epoch     6, train loss 0.680168, train error 24.68,  val loss 1.224864, percent error 45.30
# Epoch     7, train loss 0.552199, train error 19.62,  val loss 1.143123, percent error 40.80
# Epoch     8, train loss 0.474269, train error 16.50,  val loss 1.158550, percent error 39.70
# Epoch     9, train loss 0.434353, train error 15.20,  val loss 1.129586, percent error 40.10
# Epoch    10, train loss 0.365799, train error 12.40,  val loss 1.182809, percent error 39.40
# Epoch    11, train loss 0.300512, train error 10.00,  val loss 1.122160, percent error 38.40
# Epoch    12, train loss 0.288141, train error 9.28,  val loss 1.185515, percent error 36.20
# Epoch    13, train loss 0.277425, train error 9.82,  val loss 1.271047, percent error 37.10
# Epoch    14, train loss 0.190705, train error 5.68,  val loss 1.194729, percent error 35.70
# Epoch    15, train loss 0.204195, train error 6.95,  val loss 1.448294, percent error 36.40
# Epoch    16, train loss 0.151070, train error 4.35,  val loss 1.347816, percent error 35.30
# Epoch    17, train loss 0.151967, train error 4.57,  val loss 1.422864, percent error 36.70
# Epoch    18, train loss 0.148235, train error 4.40,  val loss 1.517750, percent error 35.00
# Epoch    19, train loss 0.109971, train error 3.12,  val loss 1.518685, percent error 34.80
# Epoch    20, train loss 0.031237, train error 0.07,  val loss 1.478744, percent error 34.40
# Epoch    21, train loss 0.016925, train error 0.00,  val loss 1.485192, percent error 33.00
# Epoch    22, train loss 0.012199, train error 0.00,  val loss 1.496777, percent error 32.70
# Epoch    23, train loss 0.009906, train error 0.00,  val loss 1.509052, percent error 32.20
# Epoch    24, train loss 0.008688, train error 0.00,  val loss 1.537476, percent error 32.30
# Epoch    25, train loss 0.007562, train error 0.00,  val loss 1.556751, percent error 31.90
# Epoch    26, train loss 0.006777, train error 0.00,  val loss 1.576964, percent error 32.50
# Epoch    27, train loss 0.006158, train error 0.00,  val loss 1.595569, percent error 32.40
# Epoch    28, train loss 0.005675, train error 0.00,  val loss 1.608112, percent error 32.20
# Epoch    29, train loss 0.005258, train error 0.00,  val loss 1.624995, percent error 32.20
# Epoch    30, train loss 0.004884, train error 0.00,  val loss 1.635011, percent error 32.30
# Epoch    31, train loss 0.004611, train error 0.00,  val loss 1.647524, percent error 32.90
# Epoch    32, train loss 0.004313, train error 0.00,  val loss 1.659206, percent error 32.10
# Epoch    33, train loss 0.004072, train error 0.00,  val loss 1.666541, percent error 32.30
# Epoch    34, train loss 0.003851, train error 0.00,  val loss 1.680746, percent error 32.10
# Epoch    35, train loss 0.003658, train error 0.00,  val loss 1.689504, percent error 32.20
# Epoch    36, train loss 0.003505, train error 0.00,  val loss 1.702681, percent error 32.10
# Epoch    37, train loss 0.003346, train error 0.00,  val loss 1.708235, percent error 32.20
# Epoch    38, train loss 0.003182, train error 0.00,  val loss 1.715386, percent error 32.50
# Epoch    39, train loss 0.003051, train error 0.00,  val loss 1.726107, percent error 32.10
# Epoch    40, train loss 0.002979, train error 0.00,  val loss 1.731121, percent error 32.40
# Epoch    41, train loss 0.002920, train error 0.00,  val loss 1.736173, percent error 32.20
# Epoch    42, train loss 0.002864, train error 0.00,  val loss 1.740679, percent error 32.00
# Epoch    43, train loss 0.002810, train error 0.00,  val loss 1.744942, percent error 31.90
# Epoch    44, train loss 0.002758, train error 0.00,  val loss 1.747906, percent error 32.10
# Epoch    45, train loss 0.002709, train error 0.00,  val loss 1.751696, percent error 32.10
# Epoch    46, train loss 0.002661, train error 0.00,  val loss 1.755362, percent error 32.10
# Epoch    47, train loss 0.002614, train error 0.00,  val loss 1.759681, percent error 32.10
# Epoch    48, train loss 0.002569, train error 0.00,  val loss 1.763985, percent error 32.00
# Epoch    49, train loss 0.002524, train error 0.00,  val loss 1.766045, percent error 31.90
# Epoch    50, train loss 0.002483, train error 0.00,  val loss 1.770579, percent error 31.90
# Epoch    51, train loss 0.002441, train error 0.00,  val loss 1.773253, percent error 32.10
# Epoch    52, train loss 0.002401, train error 0.00,  val loss 1.778057, percent error 32.10
# Epoch    53, train loss 0.002363, train error 0.00,  val loss 1.780161, percent error 32.30
# Epoch    54, train loss 0.002325, train error 0.00,  val loss 1.782729, percent error 32.20
# Epoch    55, train loss 0.002290, train error 0.00,  val loss 1.785110, percent error 32.30
# Epoch    56, train loss 0.002254, train error 0.00,  val loss 1.789850, percent error 32.20
# Epoch    57, train loss 0.002219, train error 0.00,  val loss 1.792756, percent error 32.30
# Epoch    58, train loss 0.002186, train error 0.00,  val loss 1.795160, percent error 32.30
# Epoch    59, train loss 0.002153, train error 0.00,  val loss 1.798385, percent error 32.30
# Epoch    60, train loss 0.002137, train error 0.00,  val loss 1.799932, percent error 32.30
# Epoch    61, train loss 0.002122, train error 0.00,  val loss 1.800977, percent error 32.30
# Epoch    62, train loss 0.002106, train error 0.00,  val loss 1.802449, percent error 32.30
# Epoch    63, train loss 0.002091, train error 0.00,  val loss 1.804315, percent error 32.30
# Epoch    64, train loss 0.002076, train error 0.00,  val loss 1.805318, percent error 32.20
# Epoch    65, train loss 0.002062, train error 0.00,  val loss 1.807398, percent error 32.20
# Epoch    66, train loss 0.002047, train error 0.00,  val loss 1.808988, percent error 32.30
# Epoch    67, train loss 0.002033, train error 0.00,  val loss 1.809683, percent error 32.20
# Epoch    68, train loss 0.002019, train error 0.00,  val loss 1.811688, percent error 32.20
# Epoch    69, train loss 0.002005, train error 0.00,  val loss 1.813547, percent error 32.20
# Epoch    70, train loss 0.001991, train error 0.00,  val loss 1.814090, percent error 32.30
# Epoch    71, train loss 0.001978, train error 0.00,  val loss 1.816076, percent error 32.10
# Epoch    72, train loss 0.001965, train error 0.00,  val loss 1.817246, percent error 32.20
# Epoch    73, train loss 0.001951, train error 0.00,  val loss 1.818539, percent error 32.30
# Epoch    74, train loss 0.001938, train error 0.00,  val loss 1.819423, percent error 32.30
# Epoch    75, train loss 0.001925, train error 0.00,  val loss 1.821215, percent error 32.10
# Epoch    76, train loss 0.001913, train error 0.00,  val loss 1.822491, percent error 32.10
# Epoch    77, train loss 0.001900, train error 0.00,  val loss 1.824059, percent error 32.00
# Epoch    78, train loss 0.001888, train error 0.00,  val loss 1.825201, percent error 32.00
# Epoch    79, train loss 0.001876, train error 0.00,  val loss 1.826248, percent error 32.10
# Epoch    80, train loss 0.001869, train error 0.00,  val loss 1.827092, percent error 32.10
# Epoch    81, train loss 0.001863, train error 0.00,  val loss 1.827942, percent error 32.10
# Epoch    82, train loss 0.001857, train error 0.00,  val loss 1.828280, percent error 32.10
# Epoch    83, train loss 0.001852, train error 0.00,  val loss 1.829222, percent error 32.00
# Epoch    84, train loss 0.001846, train error 0.00,  val loss 1.829954, percent error 32.10
# Epoch    85, train loss 0.001840, train error 0.00,  val loss 1.830544, percent error 32.10
# Epoch    86, train loss 0.001834, train error 0.00,  val loss 1.830795, percent error 32.20
# Epoch    87, train loss 0.001828, train error 0.00,  val loss 1.831516, percent error 32.20
# Epoch    88, train loss 0.001823, train error 0.00,  val loss 1.832378, percent error 32.20
# Epoch    89, train loss 0.001817, train error 0.00,  val loss 1.833101, percent error 32.20
# Epoch    90, train loss 0.001811, train error 0.00,  val loss 1.833508, percent error 32.20
# Epoch    91, train loss 0.001805, train error 0.00,  val loss 1.834508, percent error 32.10
# Epoch    92, train loss 0.001800, train error 0.00,  val loss 1.834743, percent error 32.20
# Epoch    93, train loss 0.001794, train error 0.00,  val loss 1.835456, percent error 32.10
# Epoch    94, train loss 0.001789, train error 0.00,  val loss 1.836350, percent error 32.10
# Epoch    95, train loss 0.001783, train error 0.00,  val loss 1.836807, percent error 32.20
# Epoch    96, train loss 0.001778, train error 0.00,  val loss 1.837576, percent error 32.10
# Epoch    97, train loss 0.001772, train error 0.00,  val loss 1.838022, percent error 32.20
# Epoch    98, train loss 0.001767, train error 0.00,  val loss 1.838481, percent error 32.10
# Epoch    99, train loss 0.001762, train error 0.00,  val loss 1.839252, percent error 32.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
