# %% [markdown]
# <a href="https://colab.research.google.com/github/joyngeno21-ui/Joy-AI-Assignment/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-v5l94vbb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-v5l94vbb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=a0db21f4f5c2591b353be18e5931088564573749b05eaa64404332900f6481ce
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gwhx6nfy/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# 1.  **At what capacity do you think the training error will become zero?**
#    The training error will likely become zero when the model's capacity (number of parameters) is equal to or slightly greater than the number of training examples. Given 4000 training examples, I predict the training error will become zero around a hidden unit capacity of 40 (since there are 40 input dimensions, a single hidden layer with 40 units would already have $40 \times 40 = 1600$ parameters, and two layers would quickly exceed 4000 parameters. For `n_hidden=40`, the model has $40 \times 40 + 40 \times 40 + 40 \times 10 = 1600+1600+400 = 3600$ parameters, which is close to the number of training examples).
#
# 2.  **At what capacity do you expect the first minima of the double descent curve to appear?**
#   The first minima typically appears in the underfitting regime, where the model is simpler and generalizes well without memorizing noise. I expect this to be at a relatively low capacity, perhaps around `n_hidden = 10` to `20`.
#
# 3.  **At what capacity do you expect the maximum of the double descent curve to appear?**
#     The peak of the double descent curve (the "critical capacity") usually occurs when the model capacity is roughly equal to the number of training data points, or slightly before the training error reaches zero. This is where the model is just complex enough to fit the training data perfectly but not yet complex enough to learn broader patterns, leading to poor generalization. Based on my prediction for training error becoming zero, I expect the maximum to appear around `n_hidden = 40` to `50`.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.300215, train error 88.47,  test loss 2.298006, test error 88.10
# Epoch   100, train loss 1.923476, train error 72.07,  test loss 1.776112, test error 69.70
# Epoch   200, train loss 1.913017, train error 71.55,  test loss 1.742819, test error 69.00
# Epoch   300, train loss 1.915194, train error 71.07,  test loss 1.762734, test error 69.45
# Epoch   400, train loss 1.910168, train error 70.88,  test loss 1.753625, test error 69.05
# Epoch   500, train loss 1.906915, train error 71.38,  test loss 1.731854, test error 69.35
# Epoch   600, train loss 1.908922, train error 71.03,  test loss 1.749815, test error 69.40
# Epoch   700, train loss 1.906968, train error 72.03,  test loss 1.736511, test error 68.45
# Epoch   800, train loss 1.905239, train error 71.47,  test loss 1.736746, test error 69.68
# Epoch   900, train loss 1.906638, train error 70.07,  test loss 1.734407, test error 68.75
# Training model with   4 hidden variables
# Epoch     0, train loss 2.303367, train error 89.97,  test loss 2.303228, test error 90.30
# Epoch   100, train loss 1.837173, train error 68.10,  test loss 1.717833, test error 68.70
# Epoch   200, train loss 1.812863, train error 67.45,  test loss 1.708908, test error 68.43
# Epoch   300, train loss 1.806995, train error 68.32,  test loss 1.706144, test error 67.97
# Epoch   400, train loss 1.796783, train error 67.12,  test loss 1.695993, test error 67.18
# Epoch   500, train loss 1.793744, train error 67.15,  test loss 1.702822, test error 67.00
# Epoch   600, train loss 1.791745, train error 67.47,  test loss 1.701595, test error 67.95
# Epoch   700, train loss 1.788913, train error 67.12,  test loss 1.694992, test error 67.65
# Epoch   800, train loss 1.794848, train error 67.68,  test loss 1.711725, test error 68.50
# Epoch   900, train loss 1.787794, train error 67.28,  test loss 1.692435, test error 67.53
# Training model with   6 hidden variables
# Epoch     0, train loss 2.249228, train error 84.62,  test loss 2.238976, test error 84.78
# Epoch   100, train loss 1.712058, train error 61.85,  test loss 1.569925, test error 61.55
# Epoch   200, train loss 1.683598, train error 61.50,  test loss 1.551265, test error 60.95
# Epoch   300, train loss 1.652389, train error 59.95,  test loss 1.526972, test error 58.97
# Epoch   400, train loss 1.633351, train error 57.85,  test loss 1.502899, test error 58.42
# Epoch   500, train loss 1.623730, train error 58.50,  test loss 1.493538, test error 58.12
# Epoch   600, train loss 1.631018, train error 58.45,  test loss 1.510502, test error 58.60
# Epoch   700, train loss 1.615340, train error 58.08,  test loss 1.510257, test error 57.22
# Epoch   800, train loss 1.608817, train error 57.78,  test loss 1.499680, test error 57.25
# Epoch   900, train loss 1.604349, train error 56.90,  test loss 1.491577, test error 57.88
# Training model with   8 hidden variables
# Epoch     0, train loss 2.256674, train error 85.18,  test loss 2.238269, test error 83.70
# Epoch   100, train loss 1.592670, train error 55.75,  test loss 1.413873, test error 54.47
# Epoch   200, train loss 1.494233, train error 50.55,  test loss 1.296172, test error 47.03
# Epoch   300, train loss 1.475372, train error 49.60,  test loss 1.290951, test error 47.10
# Epoch   400, train loss 1.464350, train error 49.65,  test loss 1.282462, test error 47.03
# Epoch   500, train loss 1.457110, train error 48.95,  test loss 1.286211, test error 47.28
# Epoch   600, train loss 1.452791, train error 48.92,  test loss 1.286136, test error 47.50
# Epoch   700, train loss 1.451498, train error 49.28,  test loss 1.281035, test error 46.85
# Epoch   800, train loss 1.446013, train error 49.15,  test loss 1.277909, test error 47.10
# Epoch   900, train loss 1.449811, train error 49.08,  test loss 1.283296, test error 47.33
# Training model with  10 hidden variables
# Epoch     0, train loss 2.249603, train error 83.45,  test loss 2.241823, test error 82.45
# Epoch   100, train loss 1.514297, train error 51.70,  test loss 1.339637, test error 49.45
# Epoch   200, train loss 1.442464, train error 48.10,  test loss 1.305609, test error 47.55
# Epoch   300, train loss 1.417877, train error 48.03,  test loss 1.294189, test error 46.70
# Epoch   400, train loss 1.409891, train error 47.88,  test loss 1.309999, test error 46.92
# Epoch   500, train loss 1.397194, train error 46.70,  test loss 1.320263, test error 47.42
# Epoch   600, train loss 1.393409, train error 46.72,  test loss 1.325413, test error 48.20
# Epoch   700, train loss 1.388599, train error 46.95,  test loss 1.321720, test error 47.83
# Epoch   800, train loss 1.387719, train error 47.10,  test loss 1.329565, test error 47.78
# Epoch   900, train loss 1.383877, train error 47.15,  test loss 1.335523, test error 47.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.244904, train error 82.43,  test loss 2.244137, test error 83.28
# Epoch   100, train loss 1.458856, train error 48.53,  test loss 1.398585, test error 53.05
# Epoch   200, train loss 1.377094, train error 45.83,  test loss 1.385422, test error 52.12
# Epoch   300, train loss 1.359191, train error 45.25,  test loss 1.404080, test error 51.60
# Epoch   400, train loss 1.332982, train error 44.28,  test loss 1.403895, test error 50.75
# Epoch   500, train loss 1.324192, train error 43.58,  test loss 1.418860, test error 51.12
# Epoch   600, train loss 1.317082, train error 44.22,  test loss 1.449763, test error 53.33
# Epoch   700, train loss 1.303307, train error 43.45,  test loss 1.437813, test error 51.92
# Epoch   800, train loss 1.297399, train error 43.75,  test loss 1.456747, test error 52.05
# Epoch   900, train loss 1.294416, train error 43.50,  test loss 1.464367, test error 52.40
# Training model with  18 hidden variables
# Epoch     0, train loss 2.187108, train error 82.20,  test loss 2.152340, test error 81.95
# Epoch   100, train loss 1.340525, train error 45.35,  test loss 1.295642, test error 49.33
# Epoch   200, train loss 1.250884, train error 43.05,  test loss 1.349407, test error 49.92
# Epoch   300, train loss 1.203038, train error 41.00,  test loss 1.403007, test error 50.12
# Epoch   400, train loss 1.178577, train error 39.40,  test loss 1.439143, test error 50.47
# Epoch   500, train loss 1.162796, train error 39.10,  test loss 1.483266, test error 51.30
# Epoch   600, train loss 1.151574, train error 39.38,  test loss 1.508056, test error 51.25
# Epoch   700, train loss 1.139103, train error 39.17,  test loss 1.532436, test error 50.88
# Epoch   800, train loss 1.133543, train error 38.62,  test loss 1.567242, test error 51.15
# Epoch   900, train loss 1.141852, train error 39.53,  test loss 1.605052, test error 52.10
# Training model with  22 hidden variables
# Epoch     0, train loss 2.224619, train error 82.22,  test loss 2.215651, test error 82.10
# Epoch   100, train loss 1.251902, train error 42.20,  test loss 1.299216, test error 48.33
# Epoch   200, train loss 1.134953, train error 37.65,  test loss 1.365111, test error 48.85
# Epoch   300, train loss 1.089489, train error 37.30,  test loss 1.434253, test error 50.85
# Epoch   400, train loss 1.066841, train error 36.62,  test loss 1.494589, test error 51.05
# Epoch   500, train loss 1.043577, train error 35.60,  test loss 1.565948, test error 51.95
# Epoch   600, train loss 1.027057, train error 34.75,  test loss 1.621155, test error 52.40
# Epoch   700, train loss 1.018217, train error 35.10,  test loss 1.648854, test error 52.47
# Epoch   800, train loss 1.011013, train error 35.38,  test loss 1.724468, test error 52.90
# Epoch   900, train loss 0.996060, train error 34.45,  test loss 1.745136, test error 53.38
# Training model with  26 hidden variables
# Epoch     0, train loss 2.158631, train error 80.45,  test loss 2.151705, test error 79.65
# Epoch   100, train loss 1.173189, train error 38.80,  test loss 1.332016, test error 49.42
# Epoch   200, train loss 1.042509, train error 34.55,  test loss 1.435724, test error 50.70
# Epoch   300, train loss 0.981454, train error 33.53,  test loss 1.530140, test error 51.35
# Epoch   400, train loss 0.942052, train error 31.88,  test loss 1.620292, test error 52.25
# Epoch   500, train loss 0.901030, train error 29.38,  test loss 1.707652, test error 52.17
# Epoch   600, train loss 0.879800, train error 28.90,  test loss 1.786992, test error 53.40
# Epoch   700, train loss 0.871419, train error 29.47,  test loss 1.881142, test error 53.62
# Epoch   800, train loss 0.866717, train error 28.93,  test loss 1.908609, test error 53.55
# Epoch   900, train loss 0.836992, train error 27.90,  test loss 1.977502, test error 54.67
# Training model with  30 hidden variables
# Epoch     0, train loss 2.161901, train error 80.43,  test loss 2.117211, test error 78.88
# Epoch   100, train loss 1.106344, train error 36.72,  test loss 1.311516, test error 47.33
# Epoch   200, train loss 0.950857, train error 32.12,  test loss 1.517110, test error 49.92
# Epoch   300, train loss 0.839129, train error 28.40,  test loss 1.663360, test error 50.53
# Epoch   400, train loss 0.776159, train error 26.15,  test loss 1.835941, test error 52.08
# Epoch   500, train loss 0.740503, train error 25.40,  test loss 2.009355, test error 53.12
# Epoch   600, train loss 0.708537, train error 25.03,  test loss 2.110025, test error 52.90
# Epoch   700, train loss 0.677524, train error 23.57,  test loss 2.291362, test error 53.60
# Epoch   800, train loss 0.657850, train error 22.65,  test loss 2.414852, test error 53.62
# Epoch   900, train loss 0.642276, train error 22.12,  test loss 2.565848, test error 54.83
# Training model with  35 hidden variables
# Epoch     0, train loss 2.087868, train error 76.95,  test loss 2.022000, test error 76.85
# Epoch   100, train loss 1.001619, train error 32.38,  test loss 1.348840, test error 49.28
# Epoch   200, train loss 0.795977, train error 25.78,  test loss 1.670609, test error 51.03
# Epoch   300, train loss 0.665571, train error 21.12,  test loss 2.027532, test error 51.80
# Epoch   400, train loss 0.602465, train error 20.38,  test loss 2.405495, test error 52.60
# Epoch   500, train loss 0.565153, train error 18.57,  test loss 2.777982, test error 54.58
# Epoch   600, train loss 0.531882, train error 17.88,  test loss 3.105995, test error 54.78
# Epoch   700, train loss 0.471127, train error 15.78,  test loss 3.373134, test error 55.47
# Epoch   800, train loss 0.508708, train error 17.05,  test loss 3.642533, test error 55.78
# Epoch   900, train loss 0.470062, train error 15.68,  test loss 3.712812, test error 55.72
# Training model with  40 hidden variables
# Epoch     0, train loss 2.088962, train error 77.47,  test loss 2.035121, test error 77.43
# Epoch   100, train loss 0.911350, train error 29.40,  test loss 1.408200, test error 49.35
# Epoch   200, train loss 0.624755, train error 20.47,  test loss 1.847501, test error 52.15
# Epoch   300, train loss 0.492839, train error 15.62,  test loss 2.471066, test error 52.97
# Epoch   400, train loss 0.417141, train error 14.07,  test loss 3.106648, test error 53.97
# Epoch   500, train loss 0.358831, train error 12.50,  test loss 3.787271, test error 54.83
# Epoch   600, train loss 0.284067, train error 9.25,  test loss 4.353274, test error 55.10
# Epoch   700, train loss 0.305814, train error 11.12,  test loss 5.180819, test error 56.35
# Epoch   800, train loss 0.254052, train error 9.60,  test loss 5.759589, test error 56.53
# Epoch   900, train loss 0.251205, train error 9.22,  test loss 6.406145, test error 56.35
# Training model with  45 hidden variables
# Epoch     0, train loss 2.061919, train error 77.25,  test loss 1.990318, test error 75.82
# Epoch   100, train loss 0.784422, train error 25.30,  test loss 1.477877, test error 49.33
# Epoch   200, train loss 0.485420, train error 15.20,  test loss 2.130769, test error 50.80
# Epoch   300, train loss 0.307680, train error 9.22,  test loss 3.148564, test error 53.70
# Epoch   400, train loss 0.179431, train error 4.85,  test loss 4.291788, test error 53.70
# Epoch   500, train loss 0.169809, train error 5.60,  test loss 5.755035, test error 56.22
# Epoch   600, train loss 0.147309, train error 4.88,  test loss 6.749008, test error 57.08
# Epoch   700, train loss 0.189135, train error 6.75,  test loss 7.687221, test error 54.95
# Epoch   800, train loss 0.186504, train error 6.18,  test loss 8.822121, test error 56.90
# Epoch   900, train loss 0.003965, train error 0.00,  test loss 9.398870, test error 56.08
# Training model with  50 hidden variables
# Epoch     0, train loss 2.092105, train error 77.22,  test loss 2.050512, test error 76.62
# Epoch   100, train loss 0.733183, train error 23.45,  test loss 1.582661, test error 51.05
# Epoch   200, train loss 0.375531, train error 12.05,  test loss 2.739617, test error 54.92
# Epoch   300, train loss 0.170081, train error 4.43,  test loss 4.372172, test error 56.97
# Epoch   400, train loss 0.068615, train error 1.12,  test loss 6.215696, test error 57.58
# Epoch   500, train loss 0.013132, train error 0.00,  test loss 7.136351, test error 56.15
# Epoch   600, train loss 0.008191, train error 0.00,  test loss 7.809497, test error 56.17
# Epoch   700, train loss 0.005852, train error 0.00,  test loss 8.307287, test error 56.28
# Epoch   800, train loss 0.004480, train error 0.00,  test loss 8.711412, test error 56.45
# Epoch   900, train loss 0.003617, train error 0.00,  test loss 9.038894, test error 56.45
# Training model with  55 hidden variables
# Epoch     0, train loss 2.103673, train error 78.30,  test loss 2.066499, test error 77.10
# Epoch   100, train loss 0.636881, train error 20.68,  test loss 1.617029, test error 49.45
# Epoch   200, train loss 0.198987, train error 4.30,  test loss 2.928975, test error 52.35
# Epoch   300, train loss 0.039804, train error 0.05,  test loss 4.602414, test error 54.12
# Epoch   400, train loss 0.015157, train error 0.00,  test loss 5.593952, test error 54.67
# Epoch   500, train loss 0.008680, train error 0.00,  test loss 6.208093, test error 54.58
# Epoch   600, train loss 0.005930, train error 0.00,  test loss 6.647016, test error 54.65
# Epoch   700, train loss 0.004448, train error 0.00,  test loss 6.988716, test error 54.45
# Epoch   800, train loss 0.003521, train error 0.00,  test loss 7.271306, test error 54.53
# Epoch   900, train loss 0.002882, train error 0.00,  test loss 7.506442, test error 54.60
# Training model with  60 hidden variables
# Epoch     0, train loss 2.071697, train error 78.20,  test loss 2.018487, test error 77.18
# Epoch   100, train loss 0.567364, train error 17.75,  test loss 1.787541, test error 51.65
# Epoch   200, train loss 0.114495, train error 1.35,  test loss 3.522366, test error 55.17
# Epoch   300, train loss 0.019748, train error 0.00,  test loss 4.928028, test error 55.72
# Epoch   400, train loss 0.009503, train error 0.00,  test loss 5.644401, test error 55.70
# Epoch   500, train loss 0.006076, train error 0.00,  test loss 6.114404, test error 55.85
# Epoch   600, train loss 0.004337, train error 0.00,  test loss 6.470370, test error 55.75
# Epoch   700, train loss 0.003331, train error 0.00,  test loss 6.744754, test error 55.78
# Epoch   800, train loss 0.002688, train error 0.00,  test loss 6.975037, test error 55.65
# Epoch   900, train loss 0.002235, train error 0.00,  test loss 7.165731, test error 55.65
# Training model with  70 hidden variables
# Epoch     0, train loss 2.023839, train error 75.10,  test loss 1.978698, test error 74.43
# Epoch   100, train loss 0.364565, train error 9.60,  test loss 1.938846, test error 51.75
# Epoch   200, train loss 0.034192, train error 0.00,  test loss 3.514117, test error 53.38
# Epoch   300, train loss 0.011062, train error 0.00,  test loss 4.287864, test error 53.62
# Epoch   400, train loss 0.006135, train error 0.00,  test loss 4.719418, test error 53.47
# Epoch   500, train loss 0.004125, train error 0.00,  test loss 5.025814, test error 53.55
# Epoch   600, train loss 0.003040, train error 0.00,  test loss 5.252670, test error 53.55
# Epoch   700, train loss 0.002383, train error 0.00,  test loss 5.441063, test error 53.50
# Epoch   800, train loss 0.001945, train error 0.00,  test loss 5.595058, test error 53.60
# Epoch   900, train loss 0.001635, train error 0.00,  test loss 5.728443, test error 53.65
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019519, train error 75.30,  test loss 1.964207, test error 74.07
# Epoch   100, train loss 0.221078, train error 3.57,  test loss 2.170721, test error 51.35
# Epoch   200, train loss 0.020049, train error 0.00,  test loss 3.527815, test error 52.97
# Epoch   300, train loss 0.008161, train error 0.00,  test loss 4.108827, test error 53.35
# Epoch   400, train loss 0.004778, train error 0.00,  test loss 4.453115, test error 53.65
# Epoch   500, train loss 0.003297, train error 0.00,  test loss 4.693233, test error 53.53
# Epoch   600, train loss 0.002486, train error 0.00,  test loss 4.879623, test error 53.78
# Epoch   700, train loss 0.001970, train error 0.00,  test loss 5.037494, test error 53.90
# Epoch   800, train loss 0.001622, train error 0.00,  test loss 5.167681, test error 53.80
# Epoch   900, train loss 0.001371, train error 0.00,  test loss 5.280992, test error 53.85
# Training model with  90 hidden variables
# Epoch     0, train loss 2.005389, train error 75.15,  test loss 1.940218, test error 74.53
# Epoch   100, train loss 0.137715, train error 1.10,  test loss 2.234325, test error 51.97
# Epoch   200, train loss 0.014618, train error 0.00,  test loss 3.274431, test error 52.58
# Epoch   300, train loss 0.006490, train error 0.00,  test loss 3.703881, test error 52.45
# Epoch   400, train loss 0.003970, train error 0.00,  test loss 3.965799, test error 52.55
# Epoch   500, train loss 0.002797, train error 0.00,  test loss 4.158036, test error 52.58
# Epoch   600, train loss 0.002131, train error 0.00,  test loss 4.305284, test error 52.55
# Epoch   700, train loss 0.001703, train error 0.00,  test loss 4.427433, test error 52.60
# Epoch   800, train loss 0.001410, train error 0.00,  test loss 4.529994, test error 52.60
# Epoch   900, train loss 0.001198, train error 0.00,  test loss 4.619379, test error 52.70
# Training model with 100 hidden variables
# Epoch     0, train loss 2.008719, train error 75.35,  test loss 1.946012, test error 74.68
# Epoch   100, train loss 0.103763, train error 0.40,  test loss 2.273918, test error 52.33
# Epoch   200, train loss 0.012836, train error 0.00,  test loss 3.166416, test error 52.50
# Epoch   300, train loss 0.005904, train error 0.00,  test loss 3.546750, test error 52.80
# Epoch   400, train loss 0.003645, train error 0.00,  test loss 3.774229, test error 52.75
# Epoch   500, train loss 0.002584, train error 0.00,  test loss 3.942137, test error 52.47
# Epoch   600, train loss 0.001977, train error 0.00,  test loss 4.073233, test error 52.55
# Epoch   700, train loss 0.001586, train error 0.00,  test loss 4.181108, test error 52.55
# Epoch   800, train loss 0.001317, train error 0.00,  test loss 4.273355, test error 52.60
# Epoch   900, train loss 0.001120, train error 0.00,  test loss 4.352764, test error 52.47
# Training model with 120 hidden variables
# Epoch     0, train loss 1.972865, train error 72.45,  test loss 1.929639, test error 75.00
# Epoch   100, train loss 0.055004, train error 0.00,  test loss 2.195459, test error 51.05
# Epoch   200, train loss 0.009829, train error 0.00,  test loss 2.822688, test error 51.28
# Epoch   300, train loss 0.004834, train error 0.00,  test loss 3.108681, test error 51.40
# Epoch   400, train loss 0.003081, train error 0.00,  test loss 3.289975, test error 51.33
# Epoch   500, train loss 0.002212, train error 0.00,  test loss 3.423085, test error 51.33
# Epoch   600, train loss 0.001707, train error 0.00,  test loss 3.527823, test error 51.53
# Epoch   700, train loss 0.001380, train error 0.00,  test loss 3.615992, test error 51.62
# Epoch   800, train loss 0.001150, train error 0.00,  test loss 3.691645, test error 51.67
# Epoch   900, train loss 0.000982, train error 0.00,  test loss 3.756172, test error 51.72
# Training model with 140 hidden variables
# Epoch     0, train loss 1.942221, train error 71.70,  test loss 1.856975, test error 72.38
# Epoch   100, train loss 0.036221, train error 0.00,  test loss 2.246739, test error 49.83
# Epoch   200, train loss 0.008160, train error 0.00,  test loss 2.765708, test error 49.88
# Epoch   300, train loss 0.004165, train error 0.00,  test loss 3.005611, test error 49.83
# Epoch   400, train loss 0.002703, train error 0.00,  test loss 3.163481, test error 50.10
# Epoch   500, train loss 0.001968, train error 0.00,  test loss 3.282000, test error 50.08
# Epoch   600, train loss 0.001529, train error 0.00,  test loss 3.373801, test error 50.12
# Epoch   700, train loss 0.001241, train error 0.00,  test loss 3.452395, test error 50.33
# Epoch   800, train loss 0.001039, train error 0.00,  test loss 3.518669, test error 50.33
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.576371, test error 50.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.959555, train error 72.43,  test loss 1.882016, test error 74.05
# Epoch   100, train loss 0.028028, train error 0.00,  test loss 2.119969, test error 49.33
# Epoch   200, train loss 0.007112, train error 0.00,  test loss 2.523313, test error 49.42
# Epoch   300, train loss 0.003761, train error 0.00,  test loss 2.726552, test error 49.70
# Epoch   400, train loss 0.002474, train error 0.00,  test loss 2.858925, test error 49.50
# Epoch   500, train loss 0.001813, train error 0.00,  test loss 2.957860, test error 49.58
# Epoch   600, train loss 0.001416, train error 0.00,  test loss 3.037413, test error 49.70
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.103170, test error 49.65
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.159760, test error 49.60
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.209292, test error 49.47
# Training model with 180 hidden variables
# Epoch     0, train loss 1.928272, train error 70.18,  test loss 1.852693, test error 71.28
# Epoch   100, train loss 0.024313, train error 0.00,  test loss 1.996790, test error 47.60
# Epoch   200, train loss 0.006580, train error 0.00,  test loss 2.328746, test error 47.50
# Epoch   300, train loss 0.003524, train error 0.00,  test loss 2.496358, test error 47.62
# Epoch   400, train loss 0.002335, train error 0.00,  test loss 2.608275, test error 47.75
# Epoch   500, train loss 0.001718, train error 0.00,  test loss 2.692939, test error 47.67
# Epoch   600, train loss 0.001345, train error 0.00,  test loss 2.759836, test error 47.58
# Epoch   700, train loss 0.001098, train error 0.00,  test loss 2.816056, test error 47.70
# Epoch   800, train loss 0.000923, train error 0.00,  test loss 2.864084, test error 47.62
# Epoch   900, train loss 0.000793, train error 0.00,  test loss 2.906135, test error 47.58
# Training model with 200 hidden variables
# Epoch     0, train loss 1.929059, train error 70.55,  test loss 1.830772, test error 70.90
# Epoch   100, train loss 0.021208, train error 0.00,  test loss 1.980130, test error 47.85
# Epoch   200, train loss 0.006072, train error 0.00,  test loss 2.289135, test error 47.53
# Epoch   300, train loss 0.003309, train error 0.00,  test loss 2.449041, test error 47.55
# Epoch   400, train loss 0.002204, train error 0.00,  test loss 2.554049, test error 47.58
# Epoch   500, train loss 0.001628, train error 0.00,  test loss 2.634449, test error 47.67
# Epoch   600, train loss 0.001278, train error 0.00,  test loss 2.699522, test error 47.62
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.753874, test error 47.72
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.800244, test error 47.70
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.840163, test error 47.67
# Training model with 250 hidden variables
# Epoch     0, train loss 1.894350, train error 69.90,  test loss 1.804350, test error 70.28
# Epoch   100, train loss 0.017234, train error 0.00,  test loss 1.895191, test error 46.88
# Epoch   200, train loss 0.005393, train error 0.00,  test loss 2.139349, test error 46.45
# Epoch   300, train loss 0.003003, train error 0.00,  test loss 2.268770, test error 46.17
# Epoch   400, train loss 0.002024, train error 0.00,  test loss 2.357903, test error 46.40
# Epoch   500, train loss 0.001507, train error 0.00,  test loss 2.425764, test error 46.22
# Epoch   600, train loss 0.001189, train error 0.00,  test loss 2.480207, test error 46.08
# Epoch   700, train loss 0.000976, train error 0.00,  test loss 2.525601, test error 46.03
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.564973, test error 46.05
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.599327, test error 46.10
# Training model with 300 hidden variables
# Epoch     0, train loss 1.888250, train error 69.22,  test loss 1.820413, test error 70.35
# Epoch   100, train loss 0.014234, train error 0.00,  test loss 1.900643, test error 47.15
# Epoch   200, train loss 0.004738, train error 0.00,  test loss 2.116018, test error 46.70
# Epoch   300, train loss 0.002687, train error 0.00,  test loss 2.234949, test error 46.38
# Epoch   400, train loss 0.001830, train error 0.00,  test loss 2.316050, test error 46.40
# Epoch   500, train loss 0.001370, train error 0.00,  test loss 2.378324, test error 46.30
# Epoch   600, train loss 0.001085, train error 0.00,  test loss 2.428251, test error 46.35
# Epoch   700, train loss 0.000893, train error 0.00,  test loss 2.469613, test error 46.35
# Epoch   800, train loss 0.000756, train error 0.00,  test loss 2.506014, test error 46.28
# Epoch   900, train loss 0.000653, train error 0.00,  test loss 2.537528, test error 46.20
# Training model with 400 hidden variables
# Epoch     0, train loss 1.852318, train error 65.85,  test loss 1.780413, test error 67.80
# Epoch   100, train loss 0.011738, train error 0.00,  test loss 1.762070, test error 46.20
# Epoch   200, train loss 0.004179, train error 0.00,  test loss 1.933943, test error 45.90
# Epoch   300, train loss 0.002420, train error 0.00,  test loss 2.031705, test error 45.62
# Epoch   400, train loss 0.001666, train error 0.00,  test loss 2.099263, test error 45.62
# Epoch   500, train loss 0.001256, train error 0.00,  test loss 2.150990, test error 45.58
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.192952, test error 45.47
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.228189, test error 45.50
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.258862, test error 45.50
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.285877, test error 45.50

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
